# %%
from pandas import read_csv
import matplotlib.pyplot as plt

df = read_csv('dataset_2/air_quality_tabular.csv')

# %%
 df.ALARM.value_counts()
# Out:
# Safe      152305
# Danger     16968
# Name: ALARM, dtype: int64

# %%
classes = df.ALARM.value_counts().to_dict()

plt.title('Class distribution', pad=10.0)
plt.ylabel('Frequency', labelpad=10.0)
plt.xlabel('Class', labelpad=10.0)
plt.bar(classes.keys(), classes.values(), color=['green', 'red'])
plt.tight_layout()
